# %%
def engagement_rate_instagram(followers, likes, comments, shares):
    # TODO: code this function - LINH
    return (likes + comments + shares)/ followers * 100
    
def engagement_rate_twitter(followers, likes, retweets):
    # TODO: code this function - RYAN
    
def engagement_rate_facebook(followers, reactions, comments, shares):
    # TODO: code this function - DINORAH

def validate_if_string(my_string):
    # TODO: RYAN

def alidate_if_integer(prompt):
    # TODO: DINORAH

def user_input_and_print():
    platform = ''
    followers = 0
    likes = 0 #Insta, Twitter
    reactions = 0 #Facebook
    comments = 0 #Insta, Facebook
    retweets = 0
    shares = 0 #Insta, Facebook

    number_of_posts = int(input('How many posts do you want to analyze? '))
    # TODO: validate the number_of_posts as integer
    
    for post in range(number_of_posts):
        platform = input('Enter the platform (Instagram, Twitter, Facebook): ')
        # TODO: Validate if string
        
        if validate_if_string(platform) == False:
            print('Wrong input.')
        else:
            if platform == 'Instagram':
                followers = int(input('Enter the total number of followers: '))
                # TODO: call the function to validate if int
                likes = int(input('Enter the total number of likes: '))
                # TODO: call the function to validate if int
                comments = int(input('Enter the total number of comments: '))
                # TODO: call the function to validate if int
                shares = int(input('Enter the total number of shares: '))
                # TODO: call the function to validate if int
                engagement_rate = engagement_rate_instagram(followers, likes, comments, shares)
                formated_engagement_rate = f'{engagement_rate:.2f}'
                print('The engagement rate for Post ' + str(post + 1) + ' on ' + platform + ' is: ' + formated_engagement_rate + '%')

        # TODO: if for Twitter - RYAN

        # TODO: if for Facebook - DINORAH

# Call the function
user_input_and_print()
